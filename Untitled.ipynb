# %%
import numpy as np
from PIL import Image
from image_processing import create_combined_image
from utils.plot import plot_combined_result

# %%
image3 = Image.open(r"C:\Users\samil\Desktop\Cosas de Samil Alberto\TOTI\Python\Bootcamp Python DIO\image-processing-package\tests\imagem_teste\image3.jpg")
image4 = Image.open(r"C:\Users\samil\Desktop\Cosas de Samil Alberto\TOTI\Python\Bootcamp Python DIO\image-processing-package\tests\imagem_teste\image4.jpg")

# %%
image4 = image4.resize(image3.size)

# %%
image3_np = np.array(image3)
image4_np = np.array(image4)

# %%
combined_image = create_combined_image(image3_np, image4_np)

# %%
plot_combined_result(image3_np, image4_np, combined_image)
